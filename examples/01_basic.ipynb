# %% [markdown]
# <link rel="stylesheet" href="https://lean-lang.org/lean4/doc/alectryon.css">

# %%
def f := 2
# Out:
# env: 0
# message_dict: {}
# sent:
#   cmd: def f := 2
#   env: null

# %%
#check f
# Out:
# env: 1
# message_dict:
#   1:
#   - &id001
#     data: 'f : Nat'
#     endPos:
#       column: 6
#       line: 1
#     pos:
#       column: 0
#       line: 1
#     severity: info
# messages:
# - *id001
# sent:
#   cmd: '#check f'
#   env: 0

# %%
#check g
# Out:
# env: 2
# message_dict:
#   1:
#   - &id001
#     data: 'f : Nat'
#     endPos:
#       column: 6
#       line: 1
#     pos:
#       column: 0
#       line: 1
#     severity: info
#   - &id002
#     data: unknown identifier 'g'
#     endPos:
#       column: 8
#       line: 1
#     pos:
#       column: 7
#       line: 1
#     severity: error
# messages:
# - *id001
# - *id002
# sent:
#   cmd: '#check g'
#   env: 1

# %%
example : 1 = 2 := sorry
# Out:
# env: 3
# message_dict:
#   1:
#   - &id001
#     data: 'f : Nat'
#     endPos:
#       column: 6
#       line: 1
#     pos:
#       column: 0
#       line: 1
#     severity: info
#   - &id002
#     data: unknown identifier 'g'
#     endPos:
#       column: 8
#       line: 1
#     pos:
#       column: 7
#       line: 1
#     severity: error
#   - &id003
#     data: declaration uses 'sorry'
#     endPos:
#       column: 7
#       line: 1
#     pos:
#       column: 0
#       line: 1
#     severity: warning
# messages:
# - *id001
# - *id002
# - *id003
# sent:
#   cmd: 'example : 1 = 2 := sorry'
#   env: 2
# sorries:
# - endPos:
#     column: 24
#     line: 1
#   goal: "\u22A2 1 = 2"
#   pos:
#     column: 19
#     line: 1
#   proofState: 0
